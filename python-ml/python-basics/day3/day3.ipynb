# %% [markdown]
# # Day-3

# %% [markdown]
# ### Agenda
# - interpreter, coding environment, commenting
# - reading code, identation, camelcase and others
# - string and methods

# %% [markdown]
# - **interpreter**: the tool used to convert python code to output
# - **coding environment**: visual studio, sublim, vim, vi, and normal code editor.
# - **commenting**: comment is needed because it helps others understand your code, and also a good future reference.
# - **reading code**: reading others code helps learn new tricks and techniques, or shortcut methods
# - **identation**: identation is the layout of our code, it helps in easy understanding of code.
# - **ways to write file names**: CamelCase, this-way, this_way, otherWay

# %% [markdown]
# ### string and methods and solving question

# %%
name="Sanjay singh gurjar   "
multis=''' 
so this is a multi line string
'''

# %%
name[0:]
# Out:
# 'Sanjay singh gurjar'

# %%
name[0:4]
# Out:
# 'Sanj'

# %%
name[0:10]
# Out:
# 'Sanjay sin'

# %%
name[:4]
# Out:
# 'Sanj'

# %%
## string functions:
name.upper()
# Out:
# 'SANJAY SINGH GURJAR'

# %%
name.lower()
# Out:
# 'sanjay singh gurjar   '

# %%
name.split()
# Out:
# ['Sanjay', 'singh', 'gurjar']

# %%
name.strip()
# Out:
# 'Sanjay singh gurjar'

# %%
name.replace("S", "P")
# Out:
# 'Panjay singh gurjar   '

# %%
a="mimo "
b="mimi"
a+b
# Out:
# 'mimo mimi'

# %%
name.split?
# Out:
# Signature: name.split(sep=None, maxsplit=-1)
# Docstring:
# Return a list of the substrings in the string, using sep as the separator string.
#
#   sep
#     The separator used to split the string.
#
#     When set to None (the default value), will split on any whitespace
#     character (including \n \r \t \f and spaces) and will discard
#     empty strings from the result.
#   maxsplit
#     Maximum number of splits.
#     -1 (the default value) means no limit.
#
# Splitting starts at the front of the string and works to the end.
#
# Note, str.split() is mainly useful for data that has been intentionally
# delimited.  With natural text that includes punctuation, consider using
# the regular expression module.
# Type:      builtin_function_or_method

# %% [markdown]
# ## questions:
# 1. store values of string in a list
# 2. store values of list into a string
# 3. add two strings of name and surname
# 4. reverse a string
# 5. uppercase a string
# 6. lowercase a string
# 7. find words in a string
# 8. find words that start with a in a string
