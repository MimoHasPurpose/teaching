# %% [markdown]
# ## d4

# %% [markdown]
# - reading code, identation, camelcase and others
# - test
# - strings, project

# %% [markdown]
# #### Notes:

# %% [markdown]
# #### Improving logic:
# - what?
# - why?
# - how?
# - techniques!!
